# %%
# Importaciones necesarias
import pandas as pd
from email.mime.application import MIMEApplication
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
import base64


import math  # Necesario para verificar NaN
import os

#Conexion con GCP
from google.colab import auth
from google.cloud import bigquery

# %%
#Cargar los datos desde GCP

# Autenticación
auth.authenticate_user()

# Proyecto y cliente de BigQuery
project_id = 'bi-fcom-drmb-local-pe-sbx'
client = bigquery.Client(project=project_id)

# Consulta
query = f"""
    select * from  bi-fcom-drmb-local-pe-sbx.VL_PE.cambio_tallas_sku
"""

# Cargar el DataFrame
df = client.query(query).to_dataframe()

# Ver las primeras filas del DataFrame
df.head()
# Out:
#   sellerID         seller  nombre_legal_seller          RUC phone_number  \
# 0  SCE4885     COMPUCIBER       COMPUCIBER SAC  20602054455    946378993
# 1  SCE4885     COMPUCIBER       COMPUCIBER SAC  20602054455    946378993
# 2  SCAF160   MINARI GROUP  MINARI GROUP S.A.C.  20610279181    914725549
# 3  SCDC69D     EBESTPRICE           OBCORP SAC  20601908191    959018538
# 4  SC1932E  Innova Cercad      Hirpanoca Ochoa  10735231117    959383348
#
#                                email legal_representative_phone  \
# 0          compuciber.es@hotmail.com                  946378993
# 1          compuciber.es@hotmail.com                  946378993
# 2           minari.group@hotmail.com                  914725549
# 3  postventa.obcorporation@gmail.com                  959018538
# 4               chirpanoca@gmail.com                  959383348
#
#           legal_representative_email main_warehouse_phone  \
# 0          compuciber.es@hotmail.com            946378993
# 1          compuciber.es@hotmail.com            946378993
# 2           minari.group@hotmail.com            953489352
# 3  postventa.obcorporation@gmail.com            959018538
# 4               chirpanoca@gmail.com            959383348
#
#                 main_warehouse_email             return_warehouse_email  \
# 0          compuciber.es@hotmail.com          compuciber.es@hotmail.com
# 1          compuciber.es@hotmail.com          compuciber.es@hotmail.com
# 2           minari.group@hotmail.com           minari.group@hotmail.com
# 3  postventa.obcorporation@gmail.com  postventa.obcorporation@gmail.com
# 4               chirpanoca@gmail.com               chirpanoca@gmail.com
#
#   return_warehouse_phone        sku      sku_seller  \
# 0              946378993  128511900        25687458
# 1              946378993  128530593  LS24C360EALXPE
# 2              953489352  117198552       MI-000494
# 3              959018538  115780204       SLS990001
# 4              959383348  128149415         VA2433.
#
#                                             sku_name last_size_update  \
# 0        MONITOR LG 19M38H-B19″ LED1366X768 VGA HDMI       2024-02-19
# 1           MONITOR SAMSUNG IPS CURVO LS24C360EALXPE       2024-02-19
# 2  Set Organizadores Maleta Bolsas Impermeable pa...       2024-02-15
# 3  Silla Gamer Ergonómica Dreizt Shine Series Neg...       2024-02-15
# 4  Monitor ViewSonic VA2433-H 24" Full HD 1080P  ...       2024-02-15
#
#   new_item_size previous_item_size main_warehouse_email_prueba  \
# 0             M                  S      hhuamant@falabella.com
# 1             M                  S      hhuamant@falabella.com
# 2             M                XS2      hhuamant@falabella.com
# 3             M                  L      hhuamant@falabella.com
# 4             M                  S      hhuamant@falabella.com
#
#   return_warehouse_email_prueba
# 0        sgarciaf@falabella.com
# 1        sgarciaf@falabella.com
# 2        sgarciaf@falabella.com
# 3        sgarciaf@falabella.com
# 4        sgarciaf@falabella.com

# %%
#Guardar en un Excel para hacer las pruebas

# df.to_excel('df.xlsx', index=False)

# %%
# Importación del archivo Excel df, par alas pruebas

# df_pruebas = pd.read_excel('/content/df.xlsx')

# %%
#Visualizar el df de pruebas
# Convert the data to a Pandas DataFrame
df.head(20)
# Out:
#    sellerID                   seller  \
# 0   SCE4885               COMPUCIBER
# 1   SCE4885               COMPUCIBER
# 2   SCAF160             MINARI GROUP
# 3   SCDC69D               EBESTPRICE
# 4   SC1932E            Innova Cercad
# 5   SCCD68C  Tecsoft Computer S.A.C.
# 6   SCF310A          PUNTO SPORTIVO.
# 7   SCF310A          PUNTO SPORTIVO.
# 8   SCF310A          PUNTO SPORTIVO.
# 9   SCF310A          PUNTO SPORTIVO.
# 10  SCF310A          PUNTO SPORTIVO.
# 11  SCF310A          PUNTO SPORTIVO.
# 12  SCF310A          PUNTO SPORTIVO.
# 13  SCF310A          PUNTO SPORTIVO.
# 14  SCF310A          PUNTO SPORTIVO.
# 15  SCF310A          PUNTO SPORTIVO.
# 16  SCF310A          PUNTO SPORTIVO.
# 17  SCF310A          PUNTO SPORTIVO.
# 18  SCF310A          PUNTO SPORTIVO.
# 19  SCF310A          PUNTO SPORTIVO.
#
#                                   nombre_legal_seller          RUC  \
# 0                                      COMPUCIBER SAC  20602054455
# 1                                      COMPUCIBER SAC  20602054455
# 2                                 MINARI GROUP S.A.C.  20610279181
# 3                                          OBCORP SAC  20601908191
# 4                                     Hirpanoca Ochoa  10735231117
# 5                             TECSOFT COMPUTER S.A.C.  20504399509
# 6   SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 7   SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 8   SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 9   SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 10  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 11  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 12  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 13  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 14  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 15  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 16  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 17  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 18  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
# 19  SGS SPORT EMPRESA INDIVIDUAL DE RESPONSABILIDA...  20610981021
#
#    phone_number                                email  \
# 0     946378993            compuciber.es@hotmail.com
# 1     946378993            compuciber.es@hotmail.com
# 2     914725549             minari.group@hotmail.com
# 3     959018538    postventa.obcorporation@gmail.com
# 4     959383348                 chirpanoca@gmail.com
# 5     998324042        ventas@tecsoftcomputer.com.pe
# 6     998354487  administracionsgs@puntosportivo.com
# 7     998354487  administracionsgs@puntosportivo.com
# 8     998354487  administracionsgs@puntosportivo.com
# 9     998354487  administracionsgs@puntosportivo.com
# 10    998354487  administracionsgs@puntosportivo.com
# 11    998354487  administracionsgs@puntosportivo.com
# 12    998354487  administracionsgs@puntosportivo.com
# 13    998354487  administracionsgs@puntosportivo.com
# 14    998354487  administracionsgs@puntosportivo.com
# 15    998354487  administracionsgs@puntosportivo.com
# 16    998354487  administracionsgs@puntosportivo.com
# 17    998354487  administracionsgs@puntosportivo.com
# 18    998354487  administracionsgs@puntosportivo.com
# 19    998354487  administracionsgs@puntosportivo.com
#
#    legal_representative_phone           legal_representative_email  \
# 0                   946378993            compuciber.es@hotmail.com
# 1                   946378993            compuciber.es@hotmail.com
# 2                   914725549             minari.group@hotmail.com
# 3                   959018538    postventa.obcorporation@gmail.com
# 4                   959383348                 chirpanoca@gmail.com
# 5                   998324042        ventas@tecsoftcomputer.com.pe
# 6                   998354487  administracionsgs@puntosportivo.com
# 7                   998354487  administracionsgs@puntosportivo.com
# 8                   998354487  administracionsgs@puntosportivo.com
# 9                   998354487  administracionsgs@puntosportivo.com
# 10                  998354487  administracionsgs@puntosportivo.com
# 11                  998354487  administracionsgs@puntosportivo.com
# 12                  998354487  administracionsgs@puntosportivo.com
# 13                  998354487  administracionsgs@puntosportivo.com
# 14                  998354487  administracionsgs@puntosportivo.com
# 15                  998354487  administracionsgs@puntosportivo.com
# 16                  998354487  administracionsgs@puntosportivo.com
# 17                  998354487  administracionsgs@puntosportivo.com
# 18                  998354487  administracionsgs@puntosportivo.com
# 19                  998354487  administracionsgs@puntosportivo.com
#
#    main_warehouse_phone                 main_warehouse_email  \
# 0             946378993            compuciber.es@hotmail.com
# 1             946378993            compuciber.es@hotmail.com
# 2             953489352             minari.group@hotmail.com
# 3             959018538    postventa.obcorporation@gmail.com
# 4             959383348                 chirpanoca@gmail.com
# 5             998324042        ventas@tecsoftcomputer.com.pe
# 6             912854010  administracionsgs@puntosportivo.com
# 7             912854010  administracionsgs@puntosportivo.com
# 8             912854010  administracionsgs@puntosportivo.com
# 9             912854010  administracionsgs@puntosportivo.com
# 10            912854010  administracionsgs@puntosportivo.com
# 11            912854010  administracionsgs@puntosportivo.com
# 12            912854010  administracionsgs@puntosportivo.com
# 13            912854010  administracionsgs@puntosportivo.com
# 14            912854010  administracionsgs@puntosportivo.com
# 15            912854010  administracionsgs@puntosportivo.com
# 16            912854010  administracionsgs@puntosportivo.com
# 17            912854010  administracionsgs@puntosportivo.com
# 18            912854010  administracionsgs@puntosportivo.com
# 19            912854010  administracionsgs@puntosportivo.com
#
#                  return_warehouse_email return_warehouse_phone        sku  \
# 0             compuciber.es@hotmail.com              946378993  128511900
# 1             compuciber.es@hotmail.com              946378993  128530593
# 2              minari.group@hotmail.com              953489352  117198552
# 3     postventa.obcorporation@gmail.com              959018538  115780204
# 4                  chirpanoca@gmail.com              959383348  128149415
# 5         ventas@tecsoftcomputer.com.pe              998324042  128554323
# 6   administracionsgs@puntosportivo.com              912854010  126611146
# 7   administracionsgs@puntosportivo.com              912854010  126457811
# 8   administracionsgs@puntosportivo.com              912854010  126611141
# 9   administracionsgs@puntosportivo.com              912854010  126611144
# 10  administracionsgs@puntosportivo.com              912854010  126457808
# 11  administracionsgs@puntosportivo.com              912854010  128090695
# 12  administracionsgs@puntosportivo.com              912854010  126611142
# 13  administracionsgs@puntosportivo.com              912854010  128090694
# 14  administracionsgs@puntosportivo.com              912854010  126457809
# 15  administracionsgs@puntosportivo.com              912854010  128090691
# 16  administracionsgs@puntosportivo.com              912854010  128090693
# 17  administracionsgs@puntosportivo.com              912854010  128090696
# 18  administracionsgs@puntosportivo.com              912854010  127914505
# 19  administracionsgs@puntosportivo.com              912854010  126457810
#
#                                  sku_seller  \
# 0                                  25687458
# 1                            LS24C360EALXPE
# 2                                 MI-000494
# 3                                 SLS990001
# 4                                   VA2433.
# 5                                 24MP60G-B
# 6                             149523BKHPT55
# 7   39321402T65_DELETED_2023-11-20_21-28-50
# 8                              149523BKHPT8
# 9                             149523BKHPT65
# 10   39321402T8_DELETED_2023-11-20_21-28-50
# 11                              39229002T85
# 12                            149523BKHPT75
# 13                               39229002T9
# 14  39321402T75_DELETED_2023-11-20_21-28-50
# 15                             39229002T105
# 16                              39229002T95
# 17                               39229002T8
# 18                             149523BKHPT7
# 19   39321402T7_DELETED_2023-11-20_21-28-50
#
#                                              sku_name last_size_update  \
# 0         MONITOR LG 19M38H-B19″ LED1366X768 VGA HDMI       2024-02-19
# 1            MONITOR SAMSUNG IPS CURVO LS24C360EALXPE       2024-02-19
# 2   Set Organizadores Maleta Bolsas Impermeable pa...       2024-02-15
# 3   Silla Gamer Ergonómica Dreizt Shine Series Neg...       2024-02-15
# 4   Monitor ViewSonic VA2433-H 24" Full HD 1080P  ...       2024-02-15
# 5   Monitor gaming LG IPS 1920x1080p 24MP60G-B Fre...       2024-02-20
# 6   Zapatilla Summits-Perfect Views 149523BKHP Neg...       2024-02-16
# 7   Zapatilla Puma Carina 2.0 POP-Up Metallics 393...       2024-02-16
# 8   Zapatilla Summits-Perfect Views 149523BKHP Neg...       2024-02-16
# 9   Zapatilla Summits-Perfect Views 149523BKHP Neg...       2024-02-16
# 10  Zapatilla Puma Carina 2.0 POP-Up Metallics 393...       2024-02-16
# 11  Zapatilla Puma caven 2.0 392290 02 Blanco para...       2024-02-16
# 12  Zapatilla Summits-Perfect Views 149523BKHP Neg...       2024-02-16
# 13  Zapatilla Puma caven 2.0 392290 02 Blanco para...       2024-02-16
# 14  Zapatilla Puma Carina 2.0 POP-Up Metallics 393...       2024-02-16
# 15  Zapatilla Puma caven 2.0 392290 02 Blanco para...       2024-02-16
# 16  Zapatilla Puma caven 2.0 392290 02 Blanco para...       2024-02-16
# 17  Zapatilla Puma caven 2.0 392290 02 Blanco para...       2024-02-16
# 18  Zapatilla Summits-Perfect Views 149523BKHP Neg...       2024-02-16
# 19  Zapatilla Puma Carina 2.0 POP-Up Metallics 393...       2024-02-16
#
#    new_item_size previous_item_size main_warehouse_email_prueba  \
# 0              M                  S      hhuamant@falabella.com
# 1              M                  S      hhuamant@falabella.com
# 2              M                XS2      hhuamant@falabella.com
# 3              M                  L      hhuamant@falabella.com
# 4              M                  S      hhuamant@falabella.com
# 5              M                 XS      hhuamant@falabella.com
# 6             XS                XS2      hhuamant@falabella.com
# 7             XS                XS2      hhuamant@falabella.com
# 8             XS                XS2      hhuamant@falabella.com
# 9             XS                XS2      hhuamant@falabella.com
# 10            XS                XS2      hhuamant@falabella.com
# 11            XS                XS2      hhuamant@falabella.com
# 12            XS                XS2      hhuamant@falabella.com
# 13            XS                XS2      hhuamant@falabella.com
# 14            XS                XS2      hhuamant@falabella.com
# 15            XS                XS2      hhuamant@falabella.com
# 16            XS                XS2      hhuamant@falabella.com
# 17            XS                XS2      hhuamant@falabella.com
# 18            XS                XS2      hhuamant@falabella.com
# 19            XS                XS2      hhuamant@falabella.com
#
#    return_warehouse_email_prueba
# 0         sgarciaf@falabella.com
# 1         sgarciaf@falabella.com
# 2         sgarciaf@falabella.com
# 3         sgarciaf@falabella.com
# 4         sgarciaf@falabella.com
# 5         sgarciaf@falabella.com
# 6         sgarciaf@falabella.com
# 7         sgarciaf@falabella.com
# 8         sgarciaf@falabella.com
# 9         sgarciaf@falabella.com
# 10        sgarciaf@falabella.com
# 11        sgarciaf@falabella.com
# 12        sgarciaf@falabella.com
# 13        sgarciaf@falabella.com
# 14        sgarciaf@falabella.com
# 15        sgarciaf@falabella.com
# 16        sgarciaf@falabella.com
# 17        sgarciaf@falabella.com
# 18        sgarciaf@falabella.com
# 19        sgarciaf@falabella.com

# %%
#Seleccionar los campos necesarios "sku" , "sku_seller", "last_size_update" , "new_item_size" , "previous_item_size"
#Los encabezados tomarian nombre de "SKU" , "Sku_Seller", "Fecha_Modificación" , "Nueva_Talla_SKU" , "Anterior_Talla_SKU"

# df_campos_utiles = df.loc[:, ["sellerID","seller", "sku", "sku_seller", "last_size_update", "new_item_size", "previous_item_size","main_warehouse_email_prueba","return_warehouse_email_prueba"]]
df_campos_utiles = df.loc[:, ["sellerID","seller", "sku", "sku_seller", "last_size_update", "new_item_size", "previous_item_size","main_warehouse_email","return_warehouse_email"]]

# Visualizar el nuevo DataFrame
df_campos_utiles.head(132)
# Out:
#     sellerID          seller        sku                     sku_seller  \
# 0    SCE4885      COMPUCIBER  128511900                       25687458
# 1    SCE4885      COMPUCIBER  128530593                 LS24C360EALXPE
# 2    SCAF160    MINARI GROUP  117198552                      MI-000494
# 3    SCDC69D      EBESTPRICE  115780204                      SLS990001
# 4    SC1932E   Innova Cercad  128149415                        VA2433.
# ..       ...             ...        ...                            ...
# 127  SC9714B         KR PERU  124242099                        2318571
# 128  SC9714B         KR PERU  124242094                        2318546
# 129  SC9714B         KR PERU  124242100                        2318577
# 130  SC9714B         KR PERU  124242098                        2318605
# 131  SCBD152  MOVILES TELCEL  126760974  MotRazr40Ultra+512Gb+12GNegro
#
#     last_size_update new_item_size previous_item_size  \
# 0         2024-02-19             M                  S
# 1         2024-02-19             M                  S
# 2         2024-02-15             M                XS2
# 3         2024-02-15             M                  L
# 4         2024-02-15             M                  S
# ..               ...           ...                ...
# 127       2024-02-19           XS3                XS2
# 128       2024-02-19           XS3                XS2
# 129       2024-02-19           XS3                XS2
# 130       2024-02-19           XS3                XS2
# 131       2024-02-17           XS3                XS2
#
#                   main_warehouse_email             return_warehouse_email
# 0            compuciber.es@hotmail.com          compuciber.es@hotmail.com
# 1            compuciber.es@hotmail.com          compuciber.es@hotmail.com
# 2             minari.group@hotmail.com           minari.group@hotmail.com
# 3    postventa.obcorporation@gmail.com  postventa.obcorporation@gmail.com
# 4                 chirpanoca@gmail.com               chirpanoca@gmail.com
# ..                                 ...                                ...
# 127           kr_falabella@hotmail.com           kr_falabella@hotmail.com
# 128           kr_falabella@hotmail.com           kr_falabella@hotmail.com
# 129           kr_falabella@hotmail.com           kr_falabella@hotmail.com
# 130           kr_falabella@hotmail.com           kr_falabella@hotmail.com
# 131         telcelmoviles297@gmail.com         telcelmoviles297@gmail.com
#
# [132 rows x 9 columns]

# %%
#Libreria para trabajar con Excel
from openpyxl.styles import Font, PatternFill
from openpyxl.utils.dataframe import dataframe_to_rows
import base64
import openpyxl

# %%
# Configuración
email_usuario = 'user@falabella.com'
contrasena = 'password.'
asunto_base = 'Cambio de tamaño de SKU'

# Establecer la conexión con el servidor SMTP de Outlook
server = smtplib.SMTP('smtp.office365.com', 587)
server.starttls()

# Iniciar sesión en el servidor SMTP
server.login(email_usuario, contrasena)

# Iterar sobre las tiendas únicas en el DataFrame
for sellerID in df_campos_utiles['sellerID'].unique():
    # Filtrar el DataFrame para la tienda actual
    df_seller = df_campos_utiles[df_campos_utiles['sellerID'] == sellerID].copy()

    # Obtener el nombre del vendedor ('seller') de la primera fila del DataFrame filtrado
    seller_name = df_seller['seller'].iloc[0]

    # Obtener la dirección de correo electrónico de la tienda actual
    # correo_seller_1 = df_seller['main_warehouse_email_prueba'].iloc[0]
    # correo_seller_2 = df_seller['return_warehouse_email_prueba'].iloc[0]
    correo_seller_1 = df_seller['main_warehouse_email'].iloc[0]
    correo_seller_2 = df_seller['return_warehouse_email'].iloc[0]


    # Verificar si la dirección de correo electrónico es NaN
    if isinstance(correo_seller_1, float) and math.isnan(correo_seller_1):
        print(f"La dirección de correo electrónico para la tienda {sellerID} es nula (NaN). No se enviará el correo.")
        continue

    # Verificar si la dirección de correo electrónico es NaN
    if isinstance(correo_seller_2, float) and math.isnan(correo_seller_2):
        print(f"La dirección de correo electrónico para la tienda {sellerID} es nula (NaN). No se enviará el correo.")
        continue

    # Configurar el mensaje
    msg = MIMEMultipart()
    msg['From'] = 'fcomlogisticasx@falabella.com'
    msg['To'] = ', '.join([correo_seller_1, correo_seller_2]) #correo_seller_2
    msg['Subject'] = f"{seller_name}: {asunto_base} "

    # Seleccionar columnas específicas para mostrar en el cuerpo del correo
    columnas_seleccionadas = ["sku", "sku_seller", "last_size_update", "new_item_size", "previous_item_size"]
    df_seller_seleccionada = df_seller[columnas_seleccionadas]

    # Renombrar las columnas en el DataFrame seleccionado
    df_seller_seleccionada = df_seller_seleccionada.rename(columns={
        'last_size_update': 'Fecha modificacion',
        'new_item_size': 'Nueva talla sku',
        'previous_item_size': 'Anterior talla sku',
        'sku': 'SKU',
        'sku_seller': 'Sku_Seller'
    })

    # Convertir la columna 'last_size_update' a tipo datetime si no lo está
    df_seller_seleccionada['Fecha modificacion'] = pd.to_datetime(df_seller_seleccionada['Fecha modificacion'])

    # Formatear la columna de fechas para que solo muestre la fecha sin la hora
    df_seller_seleccionada['Fecha modificacion'] = df_seller_seleccionada['Fecha modificacion'].dt.date

    # Guardar el DataFrame de la tienda actual en un archivo Excel
    nombre_archivo_excel = f"Informe_Cambio_Tallas{sellerID}.xlsx"
    df_seller_seleccionada.to_excel(nombre_archivo_excel, index=False)

    # Dar formato al encabezado del Excel
    wb = openpyxl.load_workbook(nombre_archivo_excel)
    ws = wb.active
    encabezados = ["SKU", "Sku_Seller", "Fecha_Modificación", "Nueva_Talla_SKU", "Anterior_Talla_SKU"]
    for col, encabezado in enumerate(encabezados, start=1):
        celda = ws.cell(row=1, column=col, value=encabezado)
        celda.font = Font(bold=True, color="000000")  # Negrita y color de fuente negro
        celda.fill = PatternFill(start_color="FFA500", end_color="FFA500", fill_type="solid")  # Fondo naranja

    # Ajustar automáticamente el ancho de las columnas
    for column_cells in ws.columns:
        length = max(len(str(cell.value)) for cell in column_cells)
        ws.column_dimensions[column_cells[0].column_letter].width = length + 2

    # Guardar el libro de trabajo con los cambios realizados
    wb.save(nombre_archivo_excel)
    # Cerrar el libro de trabajo después de guardar los cambios
    wb.close()

    # Adjuntar el archivo Excel al correo electrónico
    with open(nombre_archivo_excel, "rb") as attachment:
        part = MIMEApplication(attachment.read(), Name=os.path.basename(nombre_archivo_excel))
        part['Content-Disposition'] = f'attachment; filename="{os.path.basename(nombre_archivo_excel)}"'
        msg.attach(part)

    # Codificar la imagen en base64
    ruta_imagen = "/content/Cambio_Talla.png"
    with open(ruta_imagen, "rb") as file:
        imagen_codificada = base64.b64encode(file.read()).decode('utf-8')

    # Crear el cuerpo del correo en formato HTML con la imagen incrustada
    mensaje_html = f"""
    <html>
    <body>
        <img src="data:image/png;base64,{imagen_codificada}" alt="Cambio Talla">

    </body>
    </html>
    """

    # Adjuntar el cuerpo del correo en formato HTML
    msg.attach(MIMEText(mensaje_html, 'html'))

    # Enviar el correo electrónico
    server.sendmail(email_usuario, [correo_seller_1, correo_seller_2], msg.as_string()) #correo_seller_2

    # Eliminar el archivo Excel después de enviar el correo
    os.remove(nombre_archivo_excel)

# Cerrar la conexión con el servidor SMTP
server.quit()
# Out:
# (221, b'2.0.0 Service closing transmission channel')
